# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# # 1.환경 준비
#
# - 기본 라이브러리와 대상 데이터를 가져와 이후 과정을 준비합니다.

# %%
# 라이브러리
import sys
import numpy as np
import pandas as pd
import scipy.stats as spst
    
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# 선명하게
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 2.데이터베이스 연결
#
# - 다양한 데이터베이스 관리 시스템(DBMS)가 있지만 MS SQL Server 연결을 예로 듭니다.

# %% [markdown]
# **1) 라이브러리 설치**
#
# - 구글 코랩에서 기본으로 제공되지 않는 pymssql 라이브러리를 설치합니다.

# %%
# 라이브러리 설치
#!pip install pymssql

# %% [markdown]
# **2) 라이브러리 불러오기**
#
# - 사용할 라이브러리를 불러옵니다.

# %%
# 라이브러리 불러오기
import pymssql
import pandas as pd

# %% [markdown]
# **3) SQL Server 연결**
#
# - 연결 관련 정보를 지정하여 SQL Server에 연결합니다.
# - 관련 정보와 권한을 얻기 위해서 서버 관리자의 협조가 필요할 수 있습니다.

# %%
# SQL Server 연결
mssql = pymssql.connect(host='20.194.2.187',
                        port='4331', 
                        user='Student', 
                        password='Pa$$w0rd', 
                        database='MyShop2019')

# %% [markdown]
# **4) 데이터 읽어오기**
#
# - 데이터를 조회할 쿼리문을 작성합니다.(쿼리문 학습 필요)
# - read_sql 함수를 사용해서 쿼리를 실행해 그 결과를 가져옵니다.
# - 가져온 결과는 자동으로 데이터프레임이 됩니다.

# %%
# 쿼리문
sql = """
SELECT * FROM 고객 WHERE 지역='서울'
"""
# 데이터프레임 만들기
data = pd.read_sql(sql, con=mssql) 

# 확인
data.head()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        고객코드 고객이름 성별           전화번호                     전자우편  지역          생일  \
# 0      agoh  오암기  F  010-5972-8213       memoryoh@naber.com  서울  1994-04-06
# 1  bballhan  한야구  M  010-9246-1120  baseballhan@hanmeil.com  서울  1980-08-19
# 2     bikim  김반지  F  010-6423-9450       banjikim@naber.com  서울  1972-03-06
# 3    bjlee2  이반장  F  010-9508-8779   banjanglee2@dbnuri.com  서울  1981-12-29
# 4     btlee  이발탄  M  010-8819-1022    baltanlee@hotmeil.com  서울  1980-03-08
#
#           가입일    포인트     등급
# 0  2018-08-23  10800   BEST
# 1  2019-10-15      0  HELLO
# 2  2019-05-04      0  HELLO
# 3  2019-04-27      0  HELLO
# 4  2018-07-31  19200   BEST

# %% [markdown]
# **5) SQL Server 연결 닫기**
#
# - 더 이상 사용할 필요가 없는 경우 연결을 닫습니다.

# %%
# 연결 닫기
pymssql.Connection.close(mssql)

# %% [markdown]
# # 3.데이터 탐색

# %% [markdown]
# **1) 데이터 읽어오기**
#
# - 분석 대상 데이터를 읽어옵니다.

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/jangrae/csv/master/tips.csv'
tips = pd.read_csv(path)

# 확인
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# tips[10:21] # 10~20까지 보기
tips['tip'][10:21].plot()
plt.show()

# %%
# 주식데이터 불러오기
# TitanicFile 도 가능

path ='https://bit.ly/StocksFile'
stock = pd.read_csv(path)
stock.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2000-01-03  0.936384  1.004464  0.907924  0.999442   0.858137  535796800
# 1  2000-01-04  0.966518  0.987723  0.903460  0.915179   0.785788  512377600
# 2  2000-01-05  0.926339  0.987165  0.919643  0.928571   0.797286  778321600
# 3  2000-01-06  0.947545  0.955357  0.848214  0.848214   0.728291  767972800
# 4  2000-01-07  0.861607  0.901786  0.852679  0.888393   0.762789  460734400

# %%
# 종가(Close) 확인
plt.plot(stock['Close'])
plt.show()

# %%
# 종가(Close) 확인
plt.plot(stock['Close'][:1000])
plt.show()

# %% [markdown]
# **2) 열 정보 확인**
#
# - 열 이름, 데이터 형식 등을 확인합니다.

# %%
# 열 정보 확인
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %% [markdown]
# **3) 기초 통계 정보 확인**
#
# - 개수, 평균, 최솟값, 최댓값, 표준편차, 사분위 값을 확인합니다.

# %%
# 기초통계정보 확인
tips.describe().loc['75%', 'tip']
# Out:
# 3.5625

# %% [markdown]
# **4) 범주값 확인**
#
# - 범주형 열에 대한 범주값 개수를 확인합니다.

# %%
# sex 확인
# tips['sex'].unique()

# set 으로확인
set(tips['sex'].values)
# Out:
# {'Female', 'Male'}

# %%
# smoker 확인
tips['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# time 확인
tips['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
# day 확인
tips['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %% [markdown]
# **5) 결측치 확인**
#
# - 결측치 존재 여부를 확인합니다.

# %%
# NaN 값 확인
tips.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# **6) 상관관계 확인**
#
# - 열 간의 상관관계를 확인합니다.

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# 상관관계 확인
target = 'total_bill'

# data.columns
check_list = ['total_bill', 'tip', 'size']

for v in check_list:
    corr = spst.pearsonr(tips[v],tips[target])    
    print(f'{target} 과 {v} 의 상관관계 {corr[0]}, p-value {corr[1]} ')
# Out:
# total_bill 과 total_bill 의 상관관계 1.0, p-value 0.0
# total_bill 과 tip 의 상관관계 0.6757341092113645, p-value 6.692470646863477e-34
# total_bill 과 size 의 상관관계 0.5983151309049013, p-value 4.393510142477069e-25

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#  상관관계 시각화
plt.figure(figsize = (5,5))
sns.heatmap(tips.corr(),annot = True, cmap ='Blues',cbar = False) # annotation --> 주석, cbar 컬러bar on off
plt.show()

# %% [markdown]
# # 4.데이터 시각화

# %% [markdown]
# **1) 막대 그래프**
#
# - 막대 그래프는 범주값 간의 비교 시 사용하면좋습니다.

# %%
# 막대그래프 #1
tmp = tips.groupby(by='day', as_index=False)[['tip']].count()
plt.bar(tmp['day'], tmp['tip'])
plt.show()

# %%
# 막대그래프 #2   #################################################### 중요
sns.countplot(tips['day'])
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 막대그래프 #3   #################################################### 중요
sns.countplot(x = tips['day'], order = ['Thur','Fri','Sat','Sun'])
plt.show()

# %%
# 막대그래프 #4   #################################################### 중요
sns.countplot(x = tips['day'])
plt.show()

# %%
# 막대그래프 #5   #################################################### 큰거부터 정렬
sns.countplot(x = tips['day'], order = tips['day'].value_counts().index)
plt.show()

# %% [markdown]
# **2) 히스토그램**
#
# - 히스토그램은 값 분포 확인 시 사용하면 좋습니다.

# %%
# 히스토그램
plt.hist(tips['tip'], bins=30, alpha = 0.7, edgecolor ='black') # alpha 로 옅게,
plt.show()

# %% [markdown]
# **3) 박스 그래프**
#
# - 박스 그래프는 값 분포 확인 시 사용하면 좋습니다.

# %%
# 박스 그래프 1
plt.boxplot(tips['tip'])
plt.show()

# %%
# 박스 그래프 2
tips.plot(kind = 'box')
plt.show()

# %%
# 박스 그래프 3
plt.boxplot(tips['tip'],vert = False)
plt.show()

# %%
# 데이터
a = [-3, -1, 1, 1, 2, 4, 6, 6, 7, 7, 7, 8, 8, 8, 8, 8, 8, 9, 9, 9, 9, 9, 11, 11, 13, 14, 16, 21]

# 배열 
data = np.array(a)

# 시각화
plt.boxplot(data,vert=False)
plt.grid()
plt.show()

# %%
df = pd.DataFrame(data, columns = ['val'])
df.describe() # describe 의 min max 는 실제 data에서 max min 이고
              # boxplot 의 max min 은 25% 75%  +-  1.5 * IQR연산값 보다 크고 ,작은 최소 최대값
# Out:
#              val
# count  28.000000
# mean    7.714286
# std     5.010043
# min    -3.000000
# 25%     6.000000
# 50%     8.000000
# 75%     9.000000
# max    21.000000

# %%
b = plt.boxplot(data)
plt.show()
print(b['whiskers'][0].get_ydata()) # [min. , 25%.]
print(b['whiskers'][1].get_ydata()) # [75%. , max.]
# Out:
# [6. 2.]
# [ 9. 13.]

# %% [markdown]
# **4) 산점도**
#
# - 산점도는 상관관계 확인 시 사용하면 좋습니다.

# %%
# 산점도 1
plt.scatter(tips['total_bill'], tips['tip'])
plt.show()

# %%
# 산점도 2
sns.scatterplot(x='total_bill', y ='tip' , data = tips, hue='smoker')
plt.show()

# %%
# 산점도 3
sns.regplot(x='total_bill', y ='tip' , data = tips)
plt.show()

# %%
path = 'https://bit.ly/IrisFile'
iris = pd.read_csv(path)
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 산점도 3
plt.figure(figsize =(5,5))
sns.scatterplot(x='Petal.Length', y ='Petal.Width',hue = 'Species' , data = iris)
plt.show()

# %% [markdown]
# **5) 선 그래프**
#
# - 선 그래프는 값 변경 추이 확인 시 사용하면 좋습니다.

# %%
# 선 그래프
plt.plot(tips['tip'])
plt.show()

# %%
# 주식데이터
path = 'https://bit.ly/StocksFile'
stock = pd.read_csv(path)
stock.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2000-01-03  0.936384  1.004464  0.907924  0.999442   0.858137  535796800
# 1  2000-01-04  0.966518  0.987723  0.903460  0.915179   0.785788  512377600
# 2  2000-01-05  0.926339  0.987165  0.919643  0.928571   0.797286  778321600
# 3  2000-01-06  0.947545  0.955357  0.848214  0.848214   0.728291  767972800
# 4  2000-01-07  0.861607  0.901786  0.852679  0.888393   0.762789  460734400

# %%
plt.figure(figsize = (8,5))
plt.plot(stock['Close'][5400:], marker='s')
plt.title('Apple Stock' , size =25, pad=20)
plt.grid()
plt.ylabel('Close')
plt.show()

# %% [markdown]
# # 5.데이터 변경 및 요약
#
# - 전처리 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# **1) 데이터 읽어오기**
#
# - 분석 대상 데이터를 읽어옵니다.

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/jangrae/csv/master/titanic.csv'
titanic = pd.read_csv(path)

# 상위 몇 개 행 확인
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **2) Title 열 추가**
#
# - 호칭을 갖는 Title 열을 추가합니다.

# %%
# 호칭 추출
titanic['Title'] = titanic['Name'].str.extract('([A-Za-z]+)\.', expand=False)

# 확인
titanic['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: Title, dtype: int64

# %%
# 대표 호칭 이외는 Others로 변경
main_tit_list = ['Mr', 'Miss', 'Mrs']
titanic.loc[titanic['Title'].isin(main_tit_list) == False, 'Title'] = 'Others'

# 확인
titanic['Title'].value_counts()
# Out:
# Mr        517
# Miss      182
# Mrs       125
# Others     67
# Name: Title, dtype: int64

# %% [markdown]
# **3) 결측치 처리**
#
# - 결측치를 적절한 값으로 채웁니다.

# %%
# 결측치 확인
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# dtype: int64

# %%
titanic['Age'].median() # 28.0
# Out:
# 28.0

# %%
titanic.groupby(by = 'Title')['Age'].median()
# Out:
# Title
# Miss      21.0
# Mr        30.0
# Mrs       35.0
# Others     9.0
# Name: Age, dtype: float64

# %%
titanic.groupby(by = 'Title')['Age'].transform('median')
# Out:
# 0      30.0
# 1      35.0
# 2      21.0
# 3      35.0
# 4      30.0
#        ...
# 886     9.0
# 887    21.0
# 888    21.0
# 889    30.0
# 890    30.0
# Name: Age, Length: 891, dtype: float64

# %%
# Age 결측치를 Title 별 중앙값으로 채우기
titanic['Age'].fillna(titanic.groupby('Title')['Age'].transform('median'), inplace=True)

# Embarked 최빈값으로 채우기
# titanic['Embarked'].fillna(titanic.groupby('Title')['Embarked'].transform('s'), inplace=True)
titanic['Embarked'].fillna('S',inplace = True)
# 확인
titanic.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# Title            0
# dtype: int64

# %% [markdown]
# **4) AgeGroup 열 추가**
#
# - 나이를 그룹핑한 AgeGroup 열을 추가합니다.

# %%
# AgeGroup 추가
titanic['AgeGroup'] = pd.cut(titanic['Age'], 
                             bins=[0, 16, 25, 35, 60, 100], 
                             labels=['0_16', '17_25', '26_35', '36_60', '61_100'])

# 확인
titanic['AgeGroup'].value_counts()

# %% [markdown]
# **5) Family 열 추가**
#
# - 가족 수를 갖는 Family 열을 추가합니다.

# %%
# Family 추가
titanic['Family'] = titanic['SibSp'] + titanic['Parch']

# 확인
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family
# 0      0         A/5 21171   7.2500   NaN        S    Mr       1
# 1      0          PC 17599  71.2833   C85        C   Mrs       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss       0
# 3      0            113803  53.1000  C123        S   Mrs       1
# 4      0            373450   8.0500   NaN        S    Mr       0

# %% [markdown]
# **6) Alone 열 추가**
#
# - 혼자 탑승했는 지 여부를 갖는 Alone 열을 추가합니다.

# %%
# Single 추가
titanic['Alone'] = 'No'
titanic.loc[titanic['Family'] == 0 , 'Alone'] = 'YES'


# 확인
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family Alone
# 0      0         A/5 21171   7.2500   NaN        S    Mr       1    No
# 1      0          PC 17599  71.2833   C85        C   Mrs       1    No
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss       0   YES
# 3      0            113803  53.1000  C123        S   Mrs       1    No
# 4      0            373450   8.0500   NaN        S    Mr       0   YES

# %% [markdown]
# **7) 불필요한 열 제거**
#
# - 불필요한 열을 제거합니다.

# %%
# 불필요한 열 제거
drop_cols = ['PassengerId', 'Name', 'Age', 'Ticket', 'Cabin']
titanic.drop(drop_cols ,axis = 1, inplace = True)

# 확인
titanic.head()
# Out:
#    Survived  Pclass     Sex  SibSp  Parch     Fare Embarked Title  Family  \
# 0         0       3    male      1      0   7.2500        S    Mr       1
# 1         1       1  female      1      0  71.2833        C   Mrs       1
# 2         1       3  female      0      0   7.9250        S  Miss       0
# 3         1       1  female      1      0  53.1000        S   Mrs       1
# 4         0       3    male      0      0   8.0500        S    Mr       0
#
#   Alone
# 0    No
# 1    No
# 2   YES
# 3    No
# 4   YES

# %% [markdown]
# # 6.이상치 제거
#
# - 주어진 데이터 분포 중심에서 심하게 멀리 떨어진 데이터를 이상치라고 합니다.
# - 즉, 정상 데이터라기 보다는 비정상 데이터라고 할 수 있습니다.
# - 이상치는 제대로 된 데이터 분석을 방해할 수 있으므로 적절히 처리해야 합니다.

# %% [markdown]
# **1) 데이터 읽어오기**
#
# - 분석 대상 데이터를 읽어옵니다.

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/jangrae/csv/master/airquality.csv'
air = pd.read_csv(path)

# 상위 몇 개 행 확인
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %%
# 선형보간법으로 채우기



# 확인

# %% [markdown]
# **2) 이상치 확인**
#
# - 박스 플롯을 사용하면 가장 쉽게 이상치 존재 여부를 알 수 있습니다.
# - Wind 열 데이터 분포를 확인합니다.

# %%
# 박스 플롯으로 확인
plt.boxplot(air['Wind'], vert=0)
plt.yticks([1], ['Wind'])
plt.show()

# %% [markdown]
# **박스플롯**
#
# <img src='https://raw.githubusercontent.com/jangrae/img/master/boxplot02.png' align = "left" width=500/>

# %% [markdown]
# - describe() 메소드 결과의 25%, 75% 값을 사용해 이상치를 구분할 수 있습니다.

# %%
# 이상치 경계 찾기
q1 = air.describe().loc['25%', 'Wind']
q3 = air.describe().loc['75%', 'Wind']
iqr = q3 - q1
l_bound = q1 - iqr * 1.5
u_bound = q3 + iqr * 1.5

# 확인
print('이상치 하한 경계:', l_bound)
print('이상치 상한 경계:', u_bound)
# Out:
# 이상치 하한 경계: 1.2500000000000009
# 이상치 상한 경계: 17.65

# %% [markdown]
# - 앞에서 확인한 박스 플롯에 이상치 경계를 시각화하면 이해하기 쉽습니다.

# %%
# 이상치 경계 시각화
plt.boxplot(air['Wind'], vert=0)
plt.yticks([1], ['Wind'])
plt.axvline(l_bound, color='r', linestyle='--')
plt.axvline(u_bound, color='r', linestyle='--')
plt.show()

# %% [markdown]
# - 이상치 하한 경계값보다 작은 행, 상한 경계값 보다 큰 행을 조회하면 이상치 데이터를 확인할 수 있습니다.

# %%
# 이상치 조건
cond01 = air['Wind'] < l_bound
cond02 = air['Wind'] > u_bound

# 결과 확인
air[ cond01 | cond02]
# Out:
#     Ozone  Solar.R  Wind  Temp  Month  Day
# 8     8.0     19.0  20.1    61      5    9
# 17    6.0     78.0  18.4    57      5   18
# 47   37.0    284.0  20.7    72      6   17

# %% [markdown]
# **3) 이상치 행 제거**
#
# - 필요에 따라 이상치가 있는 행을 제거할 수 있습니다.

# %%
# 이상치 조건
cond01 = air['Wind'] < l_bound
cond02 = air['Wind'] > u_bound

# 이상치 인덱스 확인
outlier = air[cond01 | cond02].index

# 이상치 행 제거
air_test = air.drop(outlier, axis=?)
# Out:
#   Input In [150]
#     air_test = air.drop(outlier, axis=?)
#                                       ^
# SyntaxError: invalid syntax

# %%
# 처리 후(air_test)
plt.boxplot(air_test['Wind'], vert=0)
plt.yticks([1], ['Wind'])
plt.show()

# %% [markdown]
# **4) 이상치 값 변경**
#
# - 필요에 따라 이상치를 다른 값으로 변경할 수 있습니다.
# - 예를 들어 이상치를 판단하는 경계값으로 변경할 수 있습니다.

# %%
# 데이터프레임 복사
air_test = air.copy()

# 처리 후(air_test)
plt.boxplot(air_test['Wind'], vert=0)
plt.yticks([1], ['Wind'])
plt.show()

# %%
# 이상치 경계 찾기
q1 = air.describe().loc['25%', 'Wind']
q3 = air.describe().loc['75%', 'Wind']
iqr = q3 - q1
l_bound = q1 - iqr * 1.5
u_bound = q3 + iqr * 1.5

# 이상치 조건
cond01 = air_test['Wind'] < l_bound
cond02 = air_test['Wind'] > u_bound

# 이상치 값 변경

# %%
# 처리 후(air_test)
plt.boxplot(air_test['Wind'], vert=0)
plt.yticks([1], ['Wind'])
plt.show()
