# %%
# 라이브러리
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as spst

# 한글폰트 지정(맑은고딕)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 고해상도
# %config InlineBackend.figure_format = 'retina'

# %%
data = pd.read_csv('df_data_chu.csv')
data.head(2)
# Out:
#    시간    연도  연휴 추석기준  연휴길이 출발지 도착지  소요시간(분)
# 0   0  2017  추석  D-3     1  서울  부산  274.466
# 1   1  2017  추석  D-3     1  서울  부산  260.141

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시간       772 non-null    int64
#  1   연도       772 non-null    int64
#  2   연휴       772 non-null    object
#  3   추석기준     772 non-null    object
#  4   연휴길이     772 non-null    int64
#  5   출발지      772 non-null    object
#  6   도착지      772 non-null    object
#  7   소요시간(분)  770 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 48.4+ KB

# %%
tmp = data.loc[(data['시간']==0) ,: ]
tmp.head(50)
# Out:
#      시간    연도  연휴 추석기준  연휴길이 출발지 도착지     소요시간(분)
# 0     0  2017  추석  D-3     1  서울  부산  274.466000
# 24    0  2017  추석  D-2     2  서울  부산  298.683000
# 48    0  2017  추석  D-1     3  서울  부산  355.149750
# 72    0  2017  추석    D     4  서울  부산  311.849500
# 96    0  2017  추석  D+1     5  서울  부산  360.060667
# 120   0  2017  추석  D+2     6  서울  부산  339.741000
# 144   0  2017  추석  D+3     7  서울  부산  265.266000
# 168   0  2018  추석  D-3     1  서울  부산  214.224500
# 192   0  2018  추석  D-2     2  서울  부산  289.741500
# 216   0  2018  추석  D-1     3  서울  부산  374.616333
# 240   0  2018  추석    D     4  서울  부산  255.433000
# 264   0  2018  추석  D+1     5  서울  부산  248.683000
# 287   0  2018  추석  D+2     6  서울  부산  251.933000
# 330   0  2019  추석  D-3     1  서울  부산  240.866000
# 354   0  2019  추석  D-2     2  서울  부산  280.758000
# 378   0  2019  추석  D-1     3  서울  부산  369.238667
# 402   0  2019  추석  D+2     6  서울  부산  285.675000
# 423   0  2019  추석  D+3     7  서울  부산  267.433000
# ...

# %%
data['날짜'] = 0
# data['날짜'].astype
data.head(2)
# Out:
#    시간    연도  연휴 추석기준  연휴길이 출발지 도착지  소요시간(분)  날짜
# 0   0  2017  추석  D-3     1  서울  부산  274.466   0
# 1   1  2017  추석  D-3     1  서울  부산  260.141   0

# %%
year_list = [2017,2018,2019,2020,2021]
D_day_list =['2017-10-04','2018-09-24','2019-09-13','2020-10-01','2021-09-21']
for num in range(len(year_list)) :
    data.loc[(data['연도'] == year_list[num] ) & (data['추석기준']=='D'),'날짜'] = D_day_list[num]
    
tmp = data.loc[data['추석기준'] =='D',:]
tmp.tail(100)
# Out:
#      시간    연도  연휴 추석기준  연휴길이 출발지 도착지     소요시간(분)          날짜
# 72    0  2017  추석    D     4  서울  부산  311.849500  2017-10-04
# 73    1  2017  추석    D     4  서울  부산  289.928750  2017-10-04
# 74    2  2017  추석    D     4  서울  부산  293.270750  2017-10-04
# 75    3  2017  추석    D     4  서울  부산  282.888333  2017-10-04
# 76    4  2017  추석    D     4  서울  부산  273.272000  2017-10-04
# ..   ..   ...  ..  ...   ...  ..  ..         ...         ...
# 701  19  2021  추석    D     4  서울  부산  319.033333  2021-09-21
# 702  20  2021  추석    D     4  서울  부산  348.916000  2021-09-21
# 703  21  2021  추석    D     4  서울  부산  303.500000  2021-09-21
# 704  22  2021  추석    D     4  서울  부산  286.183000  2021-09-21
# 705  23  2021  추석    D     4  서울  부산  279.633000  2021-09-21
#
# [96 rows x 9 columns]

# %%
data['날짜'].value_counts()
# Out:
# 0             676
# 2017-10-04     24
# 2018-09-24     24
# 2020-10-01     24
# 2021-09-21     24
# Name: 날짜, dtype: int64

# %%
data.tail(50)
# Out:
#      시간    연도  연휴 추석기준  연휴길이 출발지 도착지     소요시간(분) 날짜
# 722  16  2021  추석  D+1     5  서울  부산  258.749667  0
# 723  17  2021  추석  D+1     5  서울  부산  276.816000  0
# 724  18  2021  추석  D+1     5  서울  부산  269.541500  0
# 725  19  2021  추석  D+1     5  서울  부산  267.333000  0
# 726  20  2021  추석  D+1     5  서울  부산  250.208000  0
# 727  21  2021  추석  D+1     5  서울  부산  277.483000  0
# 728  22  2021  추석  D+1     5  서울  부산  270.683000  0
# 729  23  2021  추석  D+1     5  서울  부산  263.866000  0
# 730   0  2021  추석  D+2     6  서울  부산  225.483000  0
# 731   5  2021  추석  D+2     6  서울  부산         NaN  0
# 732   6  2021  추석  D+2     6  서울  부산  227.116000  0
# 733   7  2021  추석  D+2     6  서울  부산  236.983000  0
# 734   8  2021  추석  D+2     6  서울  부산  218.400000  0
# 735   9  2021  추석  D+2     6  서울  부산  215.458000  0
# 736  10  2021  추석  D+2     6  서울  부산  225.949500  0
# 737  11  2021  추석  D+2     6  서울  부산  236.324500  0
# 738  12  2021  추석  D+2     6  서울  부산  240.983000  0
# ...

# %%
data.shape
# Out:
# (772, 9)

# %%
data.drop('날짜',axis =1,inplace=True )
data.head(1)
# Out:
#    시간    연도  연휴 추석기준  연휴길이 출발지 도착지  소요시간(분)
# 0   0  2017  추석  D-3     1  서울  부산  274.466

# %%
tmp2 = data.copy()

# %%
tmp = pd.read_csv('df_date.csv')
tmp.drop('Unnamed: 0',axis=1 ,inplace =True)
tmp.head(2)
# Out:
#      연도 추석기준          날짜 요일  구분
# 0  2017  D-3  2017-10-01  일  연휴
# 1  2017  D-2  2017-10-02  월  평일

# %%
tmp = pd.merge(tmp2,tmp, how='outer' , on = ['연도','추석기준'])
tmp.head(50)

# ['연도', '날짜', '시간', '연휴', '추석기준', '연휴길이','출발지', '도착지', '소요시간(분)','요일','구분']
# Out:
#       시간    연도  연휴 추석기준  연휴길이 출발지 도착지     소요시간(분)          날짜 요일  구분
# 0    0.0  2017  추석  D-3   1.0  서울  부산  274.466000  2017-10-01  일  연휴
# 1    1.0  2017  추석  D-3   1.0  서울  부산  260.141000  2017-10-01  일  연휴
# 2    2.0  2017  추석  D-3   1.0  서울  부산  269.225000  2017-10-01  일  연휴
# 3    3.0  2017  추석  D-3   1.0  서울  부산  263.721667  2017-10-01  일  연휴
# 4    4.0  2017  추석  D-3   1.0  서울  부산  264.088667  2017-10-01  일  연휴
# 5    5.0  2017  추석  D-3   1.0  서울  부산  262.533000  2017-10-01  일  연휴
# 6    6.0  2017  추석  D-3   1.0  서울  부산  277.833000  2017-10-01  일  연휴
# 7    7.0  2017  추석  D-3   1.0  서울  부산  275.887000  2017-10-01  일  연휴
# 8    8.0  2017  추석  D-3   1.0  서울  부산  281.772000  2017-10-01  일  연휴
# 9    9.0  2017  추석  D-3   1.0  서울  부산  282.099750  2017-10-01  일  연휴
# 10  10.0  2017  추석  D-3   1.0  서울  부산  292.055333  2017-10-01  일  연휴
# 11  11.0  2017  추석  D-3   1.0  서울  부산  287.999667  2017-10-01  일  연휴
# 12  12.0  2017  추석  D-3   1.0  서울  부산  289.827333  2017-10-01  일  연휴
# ...

# %%
tmp.columns
# Out:
# Index(['시간', '연도', '연휴', '추석기준', '연휴길이', '출발지', '도착지', '소요시간(분)', '날짜', '요일',
#        '구분'],
#       dtype='object')

# %%
data_tmp = tmp[['연도', '날짜', '시간', '연휴', '추석기준', '연휴길이','출발지', '도착지', '소요시간(분)','요일','구분']]
data_tmp.head()
# Out:
#      연도          날짜   시간  연휴 추석기준  연휴길이 출발지 도착지     소요시간(분) 요일  구분
# 0  2017  2017-10-01  0.0  추석  D-3   1.0  서울  부산  274.466000  일  연휴
# 1  2017  2017-10-01  1.0  추석  D-3   1.0  서울  부산  260.141000  일  연휴
# 2  2017  2017-10-01  2.0  추석  D-3   1.0  서울  부산  269.225000  일  연휴
# 3  2017  2017-10-01  3.0  추석  D-3   1.0  서울  부산  263.721667  일  연휴
# 4  2017  2017-10-01  4.0  추석  D-3   1.0  서울  부산  264.088667  일  연휴

# %%
data_tmp.isna().sum()
# Out:
# 연도         0
# 날짜         0
# 시간         1
# 연휴         1
# 추석기준       0
# 연휴길이       1
# 출발지        1
# 도착지        1
# 소요시간(분)    3
# 요일         0
# 구분         0
# dtype: int64

# %%
data_tmp.drop(axis=0,index = 772,inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15696\3002617780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_tmp.drop(axis=0,index = 772,inplace=True)

# %%
data_tmp.isna().sum()
# Out:
# 연도         0
# 날짜         0
# 시간         0
# 연휴         0
# 추석기준       0
# 연휴길이       0
# 출발지        0
# 도착지        0
# 소요시간(분)    2
# 요일         0
# 구분         0
# dtype: int64

# %%
data_tmp.tail()
# Out:
#        연도          날짜    시간  연휴 추석기준  연휴길이 출발지 도착지  소요시간(분) 요일  구분
# 767  2021  2021-09-24  18.0  추석  D+3   7.0  서울  부산  277.775  금  평일
# 768  2021  2021-09-24  19.0  추석  D+3   7.0  서울  부산  286.816  금  평일
# 769  2021  2021-09-24  20.0  추석  D+3   7.0  서울  부산  301.116  금  평일
# 770  2021  2021-09-24  21.0  추석  D+3   7.0  서울  부산  315.433  금  평일
# 771  2021  2021-09-24  22.0  추석  D+3   7.0  서울  부산  329.733  금  평일

# %%
data_tmp.to_csv('df_merged_date&chu.csv')

# %%
# Out:
#      연도          날짜   시간  연휴 추석기준  연휴길이 출발지 도착지     소요시간(분) 요일  구분
# 0  2017  2017-10-01  0.0  추석  D-3   1.0  서울  부산  274.466000  일  연휴
# 1  2017  2017-10-01  1.0  추석  D-3   1.0  서울  부산  260.141000  일  연휴
# 2  2017  2017-10-01  2.0  추석  D-3   1.0  서울  부산  269.225000  일  연휴
# 3  2017  2017-10-01  3.0  추석  D-3   1.0  서울  부산  263.721667  일  연휴
# 4  2017  2017-10-01  4.0  추석  D-3   1.0  서울  부산  264.088667  일  연휴
