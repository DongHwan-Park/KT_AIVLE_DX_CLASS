# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# 한글폰트 지정(맑은고딕)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
# %config InlineBackend.figure_format = 'retina'

# %%
data_bk = pd.read_csv('용인시_충전소정보.csv')
data_bk = data_bk.drop(columns ='Unnamed: 0',axis=0)
data = data_bk.copy()

# %%
data.head()
# Out:
#           충전소명     충전소ID  충전기ID  충전기타입                            주소 상세위치  \
# 0         용인시청  ME174147      1      6           경기도 용인시 처인구 삼가동 556  NaN
# 1       포곡읍사무소  ME174148      1      6       경기도 용인시 처인구 포곡읍 포곡로 258  NaN
# 2  죽전휴게소(서울방향)  ME178002      1      6  경기도 용인시 수지구 경부고속도로 400 (죽전동)  NaN
# 3  죽전휴게소(서울방향)  ME178002      2      6  경기도 용인시 수지구 경부고속도로 400 (죽전동)  NaN
# 4  기흥휴게소(부산방향)  ME178003      1      6     경기도 용인시 기흥구 공세로 173 (공세동)  NaN
#
#       이용가능시간        lat        long 기관 아이디  ... 지역코드 지역구분 상세 코드 충전소 구분 코드  \
# 0  24시간 이용가능  37.240666  127.177375     ME  ...   41    41460.0        A0
# 1  24시간 이용가능  37.278100  127.231259     ME  ...   41    41460.0        A0
# 2  24시간 이용가능  37.332073  127.104848     ME  ...   41    41460.0        C0
# 3  24시간 이용가능  37.332073  127.104848     ME  ...   41    41460.0        C0
# 4  24시간 이용가능  37.235656  127.105021     ME  ...   41    41460.0        C0
#
#    충전소 구분 상세코드  주차료무료  충전소 안내  이용자 제한  이용제한 사유  삭제 여부  삭제 사유
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4170 entries, 0 to 4169
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   충전소명         4170 non-null   object
#  1   충전소ID        4170 non-null   object
#  2   충전기ID        4170 non-null   int64
#  3   충전기타입        4170 non-null   int64
#  4   주소           4166 non-null   object
#  5   상세위치         2150 non-null   object
#  6   이용가능시간       4055 non-null   object
#  7   lat          4170 non-null   float64
#  8   long         4170 non-null   float64
#  9   기관 아이디       4170 non-null   object
#  10  기관명          4170 non-null   object
#  11  운영기관명        4170 non-null   object
#  12  운영기관연락처      4054 non-null   object
#  13  충전기상태        4170 non-null   int64
#  14  상태갱신일시       4061 non-null   float64
#  15  마지막 충전시작일시   2897 non-null   float64
#  16  마지막 충전종료일시   2897 non-null   float64
#  17  충전중 시작일시     2755 non-null   float64
# ...

# %%
data.isna().sum()
# Out:
# 충전소명              0
# 충전소ID             0
# 충전기ID             0
# 충전기타입             0
# 주소                4
# 상세위치           2020
# 이용가능시간          115
# lat               0
# long              0
# 기관 아이디            0
# 기관명               0
# 운영기관명             0
# 운영기관연락처         116
# 충전기상태             0
# 상태갱신일시          109
# 마지막 충전시작일시     1273
# 마지막 충전종료일시     1273
# 충전중 시작일시       1415
# Unnamed: 19    4170
# 충전용량           1532
# 충전방식           1417
# 지역코드              0
# 지역구분 상세 코드        0
# 충전소 구분 코드        19
# 충전소 구분 상세코드      19
# 주차료무료            10
# 충전소 안내         3262
# 이용자 제한            0
# 이용제한 사유        1529
# 삭제 여부             0
# 삭제 사유          4170
# dtype: int64

# %% [markdown]
# # 1. 전처리
# ## 1.1 불필요한 행 삭제

# %%
del_cols = ['상세위치','기관 아이디','운영기관명','운영기관연락처','상태갱신일시','마지막 충전시작일시',
            '마지막 충전종료일시','충전중 시작일시','Unnamed: 19','충전방식','지역코드','충전소 안내','이용자 제한','이용제한 사유','삭제 여부','삭제 사유']
## 주소 66개 중 4개 용인

# 상세위치 삭제 ->'입구 진입 후 2시 방향' 등의 불필요한 정보

# 기관명만 사용 -> 기관아이디, 운영기관명, 운영기관연락처 : 삭제

# 상태갱신일시, 마지막 충전시작일시, 마지막 충전종료일시, 충전중 시작일시, Unnamed: 19 -> 불필요한 정보 삭제 

# 충전용량 : 충전용량 kW (3, 7, 50, 100, 200 ...400)

# 충전방식 : 충전방식 (단독/동시) --> 삭제

# 지역구분 상세코드에 포함되는 지역코드 삭제
    # 지역구분 상세 코드 : ex) 11680 행정구역코드 앞 2자리+법정동코드3자리

## 충전소 구분 코드 : 
## 충전소 구분 상세코드 : 

# 주차료무료 : 385 -> 무료로 가정

# 충전소 안내 (공사로 인해 이용 불가), 이용자 제한, 이용제한 사유, 삭제 여부, 삭제 사유 -> 불필요한 정보 삭제

data = data.drop(columns = del_cols, axis= 1 )
data.isna().sum()
# Out:
# 충전소명              0
# 충전소ID             0
# 충전기ID             0
# 충전기타입             0
# 주소                4
# 이용가능시간          115
# lat               0
# long              0
# 기관명               0
# 충전기상태             0
# 충전용량           1532
# 지역구분 상세 코드        0
# 충전소 구분 코드        19
# 충전소 구분 상세코드      19
# 주차료무료            10
# dtype: int64

# %% [markdown]
# #### 주소

# %% [markdown]
# #### 이용가능시간
