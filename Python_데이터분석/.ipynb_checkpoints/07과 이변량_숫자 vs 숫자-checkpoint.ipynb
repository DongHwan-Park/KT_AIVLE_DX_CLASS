# %% [markdown]
# # 이변량_숫자 vs 숫자

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as spst

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > ① 타이타닉 생존자
# ② 보스톤 시, 타운별 집값
# ③ 아이리스 꽃 분류
# ④ 뉴욕 공기 오염도

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.0.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex      Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male 22.00000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00000      1
# 2                             Heikkinen, Miss. Laina  female 26.00000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00000      1
# 4                           Allen, Mr. William Henry    male 35.00000      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171  7.25000   NaN        S
# 1      0          PC 17599 71.28330   C85        C
# 2      0  STON/O2. 3101282  7.92500   NaN        S
# 3      0            113803 53.10000  C123        S
# 4      0            373450  8.05000   NaN        S

# %%
# 아이리스 꽃 분류
iris = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0       5.10000      3.50000       1.40000      0.20000  setosa
# 1       4.90000      3.00000       1.40000      0.20000  setosa
# 2       4.70000      3.20000       1.30000      0.20000  setosa
# 3       4.60000      3.10000       1.50000      0.20000  setosa
# 4       5.00000      3.60000       1.40000      0.20000  setosa

# %%
# 보스톤 집값 데이터
        
boston = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# 뉴욕시 공기 오염도 데이터
air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv')
air['Date'] = pd.to_datetime(air['Date'])
air['Month'] = air.Date.dt.month
air['Weekday'] = air.Date.dt.weekday
air.head()
# Out:
#    Ozone   Solar.R     Wind  Temp       Date  Month  Weekday
# 0     41 190.00000  7.40000    67 1973-05-01      5        1
# 1     36 118.00000  8.00000    72 1973-05-02      5        2
# 2     12 149.00000 12.60000    74 1973-05-03      5        3
# 3     18 313.00000 11.50000    62 1973-05-04      5        4
# 4     19       NaN 14.30000    56 1973-05-05      5        5

# %% [markdown]
# ## 2.시작하기

# %% [markdown]
# * 우리가 사용하는 도구는...
#     * 두 변수와의 관계를 살펴보기 위해, 두가지 도구(시각화, 수치화)를 이용합니다.
#     * 이 도구들도 각각 한계가 있습니다. 보이는게 전부가 아님을 꼭 명심하세요!
#     * 특히 수치화 도구(가설검정 도구)는 많은 가정들이 전제 됩니다.
#     * 그래서 이번 과정에서는 그 도구를 사용하는 데에 집중합니다.

# %% [markdown]
# ----

# %% [markdown]
# ## 3.시각화

# %% [markdown]
# * 상관 분석에 대해서 이야기 해봅시다.
#     * 상관 분석은 연속형 변수 X에 대한 연속형 변수 Y의 관계를 분석할 때 사용됩니다.
#     * Scatter를 통해 시각화 합니다.
# * 가설 : 온도(x)가 상승하면 아이스크림 판매량(y)을 증가할까?
#     * 어떤 관계가 보이나요?
#     * 얼마나 강한 관계인가요?
# * 숫자 vs 숫자를 비교할 때 중요한 관점이 **‘직선’ (Linearity)**입니다.

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EC%82%B0%EC%A0%90%EB%8F%84_ex.png?raw=true' width=500/>

# %% [markdown]
# ### 1) 산점도

# %% [markdown]
# * 문법
#     * plt.scatter( x축 값, y축 값 )
#     * plt.scatter( ‘x변수’, ‘y변수’, data = dataframe이름)

# %%
plt.scatter(air['Temp'], air['Ozone'])
plt.show()

# %%
plt.scatter('Temp', 'Ozone', data = air)  # 이 형식 권장
plt.xlabel('Temp')
plt.ylabel('Ozone')
plt.show()

# %% [markdown]
# 그래프를 그렸으면, 그래프로부터 정보를 파악해야 합니다.
#
# 무엇이 보이나요?

# %% [markdown]
# - 우상향 그래프
# - 온도가 올라갈수록 오존농도의 분포도가 넓어진다.
# -

# %% [markdown]
# #### 실습
# Temp, Wind, Solar.R 과 Ozone 과의 관계를 시각화 해 봅시다.

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,3,1)
plt.scatter('Temp', 'Ozone', data = air)  # 이 형식 권장
plt.xlabel('Temp')
# plt.ylabel('Ozone')

plt.subplot(1,3,2)
plt.scatter('Wind', 'Ozone', data = air)  # 이 형식 권장
plt.xlabel('Wind')
# plt.ylabel('Ozone')

plt.subplot(1,3,3)
plt.scatter('Solar.R', 'Ozone', data = air)  # 이 형식 권장
plt.xlabel('Solar.R')
# plt.ylabel('Ozone')
plt.show()

# %%
plt.scatter('Solar.R', 'Ozone', data = air)  # 이 형식 권장
plt.xlabel('Solar.R')
plt.ylabel('Ozone')
plt.show()

# %% [markdown]
# Ozone과 가장 강한 관계의 x변수는?

# %% [markdown]
# - temp

# %% [markdown]
# * 두 변수의 관계
#     * 산점도에서 또렷한 패턴이 보인다면, 강한 관계로 볼 수 있습니다.
#     * 특히, 직선의 패턴이 보인다면

# %% [markdown]
# <img src='https://cqeacademy.com/wp-content/uploads/2018/06/Scatter-Plots-and-Correlation-Examples.png' width=800/>

# %% [markdown]
# ### 2) pairplot으로 한꺼번에 시각화 할 수 있습니다.
#
# * 숫자형 변수들에 대한 산점도를 한꺼번에 그려줍니다.
# * 그러나 **시간이 많이**걸립니다.

# %%
sns.pairplot(air)

# %% [markdown]
# ###  3) jointplot 로 살펴보기
#
# * jointplot은 산점도와 각각의 히스토그램을 함께 보여줍니다.

# %% [markdown]
# * Temp --> Ozone

# %%
sns.jointplot(x='Temp', y='Ozone', data = air)
plt.show()

# %% [markdown]
# * Wind --> Ozone

# %%
sns.jointplot(x='Wind', y='Ozone', data = air)
plt.show()

# %% [markdown]
# * Solar.R --> Ozone

# %%
sns.jointplot(x='Solar.R', y='Ozone', data = air)
plt.show()

# %% [markdown]
# 우리는 다양한 시각화를 통해서 결국은...

# %% [markdown]
# ## 4.수치화 : 상관분석

# %% [markdown]
# * 상관계수 𝑟
#     * 공분산을 표준화 한 값
#     * -1 ~ 1 사이의 값
#     * -1, 1에 가까울 수록 강한 상관관계를 나타냄.
#
# * 경험에 의한 대략의 기준(절대적인 기준이 절대 아닙니다.)
#     * 강한 : 0.5 < |𝑟| ≤ 1
#     * 중간 : 0.2 < |𝑟| ≤ 0.5
#     * 약한 : 0.1 < |𝑟| ≤ 0.2
#     * (거의)없음 : |𝑟| ≤ 0.1

# %%
import scipy.stats as spst

# %%
# 상관계수와 p-value 

spst.pearsonr(air['Temp'], air['Ozone'])# 0.68이므로 강한 상관관계
# Out:
# (0.6833717861490114, 2.197769800200274e-22)

# %% [markdown]
# 결과는 튜플로 나오는데
#
# 1. 튜플의 첫 번째 값 : 상관계수를 뜻합니다.
# 2. 두번째 값 : p-value
#     * 귀무가설 : 상관 관계가 없다.(상관계수가 0이다.)
#     * 대립가설 : 상관 관계가 있다.(상관계수가 0이 아니다.)
# 3. 주의 사항 : 값에 NaN이 있으면 계산되지 않습니다. 반드시 .notnull()로 제외하고 수행해야 합니다.

# %%
# 데이터프레임으로 부터 수치형 데이터에 대한 상관계수 구하기
air.corr()
# Out:
#            Ozone  Solar.R     Wind     Temp    Month  Weekday
# Ozone    1.00000  0.28007 -0.60548  0.68337  0.17420 -0.01290
# Solar.R  0.28007  1.00000 -0.05679  0.27584 -0.07530  0.07119
# Wind    -0.60548 -0.05679  1.00000 -0.45799 -0.17829  0.03731
# Temp     0.68337  0.27584 -0.45799  1.00000  0.42095 -0.03257
# Month    0.17420 -0.07530 -0.17829  0.42095  1.00000  0.03026
# Weekday -0.01290  0.07119  0.03731 -0.03257  0.03026  1.00000

# %% [markdown]
# 위 결과로 부터,
# 1. 같은 변수끼리 구한 값 1은 의미 없다.
# 2. 상관계수의 절대값이
#     * 1에 가까울 수록 강한 상관관계
#     * 0에 가까울 수록 약한 상관관계
# 3. +는 양의 상관관계, -는 음의 상관관계

# %% [markdown]
# * 상관계수를 heatmap으로 시각화 할 수 있습니다.

# %%
plt.figure(figsize = (6, 6))
sns.heatmap(air.corr(), annot = True, fmt = '.3f', cmap = 'RdYlBu_r',  vmin = -1, vmax = 1)
plt.show()

# %% [markdown]
# 칼라를 변경하려면 아래 링크로 가서 color map 을 확인하고 조정하세요.
# cmap(color map) : https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# ### 실습 : 상관계수
# air 데이터를 이용합니다.

# %%
air.loc[air['Solar.R'].notnull()]
# Out:
#      Ozone  Solar.R  Wind  Temp       Date  Month  Weekday
# 0       41    190.0   7.4    67 1973-05-01      5        1
# 1       36    118.0   8.0    72 1973-05-02      5        2
# 2       12    149.0  12.6    74 1973-05-03      5        3
# 3       18    313.0  11.5    62 1973-05-04      5        4
# 6       23    299.0   8.6    65 1973-05-07      5        0
# ..     ...      ...   ...   ...        ...    ...      ...
# 148     30    193.0   6.9    70 1973-09-26      9        2
# 149     23    145.0  13.2    77 1973-09-27      9        3
# 150     14    191.0  14.3    75 1973-09-28      9        4
# 151     18    131.0   8.0    76 1973-09-29      9        5
# 152     20    223.0  11.5    68 1973-09-30      9        6
#
# [146 rows x 7 columns]

# %%
# 상관계수를 구해봅시다.
# Temp --> Ozone
print(spst.pearsonr(air['Temp'], air['Ozone']))

# Wind --> Ozone
print(spst.pearsonr(air['Wind'], air['Ozone']))

# Solar.R --> Ozone 
# 결측치 삭제 후 진행  하고보니 생각보다 상관관계가 있어보임
tmp = air.loc[air['Solar.R'].notnull()]
print(spst.pearsonr(tmp['Solar.R'], tmp['Ozone']))
# Out:
# (0.6833717861490114, 2.197769800200274e-22)
# (-0.6054782354684075, 1.1255146087638192e-16)
# (0.2800681334905377, 0.0006175878788566531)

# %%
# 차트로 보는 것과 상관계수로 비교하는 것에 차이가 있나요?
air.corr()
# Out:
#             Ozone   Solar.R      Wind      Temp     Month   Weekday
# Ozone    1.000000  0.280068 -0.605478  0.683372  0.174197 -0.012900
# Solar.R  0.280068  1.000000 -0.056792  0.275840 -0.075301  0.071189
# Wind    -0.605478 -0.056792  1.000000 -0.457988 -0.178293  0.037313
# Temp     0.683372  0.275840 -0.457988  1.000000  0.420947 -0.032574
# Month    0.174197 -0.075301 -0.178293  0.420947  1.000000  0.030261
# Weekday -0.012900  0.071189  0.037313 -0.032574  0.030261  1.000000

# %% [markdown]
# ## 5.상관계수의 한계

# %% [markdown]
# * 상관계수에는 한계가 있습니다.
#
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Correlation_examples2.svg/1920px-Correlation_examples2.svg.png' width=800/>

# %% [markdown]
# * Data Saurus

# %% [markdown]
# <img src='https://damassets.autodesk.net/content/dam/autodesk/research/publications-assets/gifs/same-stats-different-graphs/DinoSequentialSmaller.gif
# ' width=800/>

# %%
ds = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/datasaurus.csv")
ds.head()
# Out:
#   dataset        x        y
# 0    dino 55.38460 97.17950
# 1    dino 51.53850 96.02560
# 2    dino 46.15380 94.48720
# 3    dino 42.82050 91.41030
# 4    dino 40.76920 88.33330

# %%
ds_names = ['dino','x_shape', 'star', 'circle', 'bullseye' ]

# %% [markdown]
# * 아래 5개 그룹의 수치화 결과(상관계수)를 보고 x와 y에 관계가 있는지 판단해 봅시다.

# %%
for i, d in enumerate(ds_names) : # enumerate 를 이용하여 i :index, d : ds_name[i] 
    temp_ds = ds.loc[ds['dataset']==d]
    corr = spst.pearsonr(temp_ds['x'], temp_ds['y'])
    print(i)
    print('상관계수 : {:.4f},  P-value : {:.4f}'.format(corr[0], corr[1]))
    print('---------------------------------------')
# Out:
# 0
# 상관계수 : -0.0645,  P-value : 0.4459
# ---------------------------------------
# 1
# 상관계수 : -0.0656,  P-value : 0.4381
# ---------------------------------------
# 2
# 상관계수 : -0.0630,  P-value : 0.4566
# ---------------------------------------
# 3
# 상관계수 : -0.0683,  P-value : 0.4190
# ---------------------------------------
# 4
# 상관계수 : -0.0686,  P-value : 0.4173
# ---------------------------------------

# %%
# 5그룹 중 x와 y가 서로 관련이 있는 것은?

# 가장 관련이 있는것은?

# %% [markdown]
# * 그렇다면, 이제 그래프들을 관찰해 봅시다.
#     * 어떤 패턴이 있나요? 아니면 아무런 패턴도 없나요?
#     * 어떤 신호가 있나요? 아니면 노이즈만 있나요?

# %%
print(enumerate(ds_names))
# Out:
# <enumerate object at 0x000002867ABCE1C0>

# %%
for i,d in enumerate(ds_names) :
    temp_ds = ds.loc[ds['dataset']==d]
    corr = spst.pearsonr(temp_ds['x'], temp_ds['y'])
    print(i, d)
    print('상관계수 : {:.4f},  P-value : {:.4f}'.format(corr[0], corr[1]))
    plt.scatter(temp_ds['x'], temp_ds['y'])
    plt.show()
# Out:
# 0 dino
# 상관계수 : -0.0645,  P-value : 0.4459
# 1 x_shape
# 상관계수 : -0.0656,  P-value : 0.4381
# 2 star
# 상관계수 : -0.0630,  P-value : 0.4566
# 3 circle
# 상관계수 : -0.0683,  P-value : 0.4190
# 4 bullseye
# 상관계수 : -0.0686,  P-value : 0.4173

# %% [markdown]
# * 이렇듯, 수치화해서 하나의 숫자로 요약하는 데에는 많은 장점이 있습니다. 그러나 한계도 분명히 있음을 알아야 합니다.

# %% [markdown]
# ----

# %% [markdown]
# # 종합실습

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > ① 카시트 매출액
# ② 보스톤 시, 타운별 집값
# ③ 아이리스 꽃 분류
# ④ 뉴욕 공기 오염도

# %%
# 카시트 매출액
path = 'https://raw.githubusercontent.com/JunhoYu/Data-Analysis/main/Carseats.csv'
carseat = pd.read_csv(path)
carseat.drop('Education', axis = 1, inplace = True)
carseat.head()
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0  9.50000        138      73           11         276    120       Bad   42
# 1 11.22000        111      48           16         260     83      Good   65
# 2 10.06000        113      35           10         269     80    Medium   59
# 3  7.40000        117     100            4         466     97    Medium   55
# 4  4.15000        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
# 아이리스 꽃 분류
iris = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0       5.10000      3.50000       1.40000      0.20000  setosa
# 1       4.90000      3.00000       1.40000      0.20000  setosa
# 2       4.70000      3.20000       1.30000      0.20000  setosa
# 3       4.60000      3.10000       1.50000      0.20000  setosa
# 4       5.00000      3.60000       1.40000      0.20000  setosa

# %%
# 보스톤 집값 데이터
boston = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston2_NA.csv')
boston.head()
# Out:
#      crim   indus  chas     nox      rm      age     dis  rad  tax  ptratio  \
# 0 0.00632 2.31000     0 0.53800 6.57500 65.20000 4.09000    1  296 15.30000
# 1 0.02731 7.07000     0 0.46900 6.42100 78.90000 4.96710    2  242 17.80000
# 2 0.02729 7.07000     0 0.46900 7.18500 61.10000 4.96710    2  242 17.80000
# 3 0.03237 2.18000     0 0.45800 6.99800 45.80000 6.06220    3  222 18.70000
# 4 0.06905 2.18000     0 0.45800 7.14700 54.20000 6.06220    3  222 18.70000
#
#       black   lstat     medv     zn2
# 0 396.90000 4.98000 24.00000 1.00000
# 1 396.90000 9.14000 21.60000 0.00000
# 2 392.83000 4.03000 34.70000 0.00000
# 3 394.63000 2.94000 33.40000 0.00000
# 4 396.90000 5.33000 36.20000 0.00000

# %%
# 뉴욕시 공기 오염도 데이터
air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv')
air['Date'] = pd.to_datetime(air['Date'])
air['Month'] = air.Date.dt.month
air['Weekday'] = air.Date.dt.weekday
air.head()
# Out:
#    Ozone   Solar.R     Wind  Temp       Date  Month  Weekday
# 0     41 190.00000  7.40000    67 1973-05-01      5        1
# 1     36 118.00000  8.00000    72 1973-05-02      5        2
# 2     12 149.00000 12.60000    74 1973-05-03      5        3
# 3     18 313.00000 11.50000    62 1973-05-04      5        4
# 4     19       NaN 14.30000    56 1973-05-05      5        5

# %% [markdown]
# ## 2.시각화

# %% [markdown]
# ### 1) 산점도 : plt.scatter, sns.scatterplot, sns.jointplot

# %%
import scipy.stats as spst

# %% [markdown]
# ① iris의 Petal.Length와 Petal.Width의 관계를 살펴보기 위해 산점도를 그려봅시다.
# * plt.scatter

# %%
plt.scatter(x = 'Petal.Length', y = 'Petal.Width', data = iris )
plt.grid()
plt.show()

# %% [markdown]
# * sns.scatterplot

# %%
sns.scatterplot(x = 'Petal.Length', y = 'Petal.Width', data = iris )
plt.grid()
plt.show()

# %% [markdown]
# * sns.scatterplot(    , hue = 'Species')

# %%
sns.scatterplot(x = 'Petal.Length', y = 'Petal.Width', data = iris ,hue = 'Species')
plt.grid()
plt.show()

# %% [markdown]
# * sns.jointplot

# %%
sns.jointplot(x = 'Petal.Length', y = 'Petal.Width', data = iris,hue = 'Species')
plt.show()

# %% [markdown]
# * 그래프로 부터 파악된 내용을 적어 봅시다.

# %% [markdown]
# - **비록 다른종들이지만 length 와 width는 서로 상관관계가 있어보인다.**

# %% [markdown]
# ② boston의 indus(비소매상업지구의 면적비율)와 medv(집값)의 관계를 살펴보기 위해 산점도를 그려봅시다.
# * plt.scatter

# %%
# plt.scatter(x = 'indus', y = 'medv', data = boston)
plt.scatter(boston['indus'], boston['medv'])
plt.grid()
plt.show()

# %% [markdown]
# * sns.scatterplot

# %%
sns.scatterplot(x = 'indus', y = 'medv', data = boston)
plt.show()

# %% [markdown]
# * sns.jointplot

# %%
sns.jointplot(x = 'indus', y = 'medv', data = boston)
plt.show()

# %% [markdown]
# * 그래프로 부터 파악된 내용을 적어 봅시다.

# %% [markdown]
# - indus 를 기준으로 3등분을 할수있어보인다 0~5 ,5~15 ,15~

# %% [markdown]
# ③ air의 Temp와 Ozone의 관계를 살펴보기 위해 산점도를 그려봅시다.
# * plt.scatter

# %%
plt.scatter('Temp', 'Ozone', data = air)
plt.show()

# %% [markdown]
# * sns.scatterplot

# %%
sns.scatterplot('Temp', 'Ozone', data = air)
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# * sns.jointplot

# %%
sns.jointplot(x ='Temp',y = 'Ozone', data = air)
plt.show()

# %% [markdown]
# * 그래프로 부터 파악된 내용을 적어 봅시다.

# %%
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp       Date  Month  Weekday
# 0     41    190.0   7.4    67 1973-05-01      5        1
# 1     36    118.0   8.0    72 1973-05-02      5        2
# 2     12    149.0  12.6    74 1973-05-03      5        3
# 3     18    313.0  11.5    62 1973-05-04      5        4
# 4     19      NaN  14.3    56 1973-05-05      5        5

# %% [markdown]
# ### 2) 한꺼번에 산점도 그리기 : sns.pairplot

# %% [markdown]
# ① air 데이터프레임에서 Month와 Day를 제외하고 산점도를 한꺼번에 그려봅시다.

# %%
tmp = air.drop(columns = ['Month','Date']  , axis = 1,)
sns.pairplot(tmp)
plt.show()

# %% [markdown]
# ② iris 데이터프레임에 대해서, Species를 제외하고 한꺼번에 산점도를 그려봅시다.

# %%
tmp = iris.drop(columns = 'Species'  , axis = 1,)
sns.pairplot(tmp)
plt.show()

# %% [markdown]
# ## 3.수치화 : 상관분석

# %%
import scipy.stats as spst

# %% [markdown]
# ① boston.indus와 boston.medv의 관계를 수치화 해 봅시다.
#
# 결과를 해석해 봅시다.

# %%
# 상관계수와 p-value

spst.pearsonr(boston['indus'], boston['medv']) # -0.48이므로 적당한상관관계 boston.inbus
# Out:
# (-0.4837251600283729, 4.900259981751351e-31)

# %% [markdown]
# ② carseat의 각 변수들 간에 상관 계수를 구해 봅시다.

# %%
carseat.corr()
# Out:
#                Sales  CompPrice   Income  Advertising  Population    Price  \
# Sales        1.00000    0.06408  0.15195      0.26951     0.05047 -0.44495
# CompPrice    0.06408    1.00000 -0.08065     -0.02420    -0.09471  0.58485
# Income       0.15195   -0.08065  1.00000      0.05899    -0.00788 -0.05670
# Advertising  0.26951   -0.02420  0.05899      1.00000     0.26565  0.04454
# Population   0.05047   -0.09471 -0.00788      0.26565     1.00000 -0.01214
# Price       -0.44495    0.58485 -0.05670      0.04454    -0.01214  1.00000
# Age         -0.23182   -0.10024 -0.00467     -0.00456    -0.04266 -0.10218
#
#                  Age
# Sales       -0.23182
# CompPrice   -0.10024
# Income      -0.00467
# Advertising -0.00456
# Population  -0.04266
# Price       -0.10218
# Age          1.00000

# %% [markdown]
# * 위 결과를 sns.heatmap()으로 그려 봅시다.

# %%
plt.figure(figsize =(12,8))
sns.heatmap(data = carseat.corr() , fmt = '.3f', annot = True, vmin = -1, vmax = 1,
           cmap = 'seismic')
plt.show()

# %% [markdown]
# ③ 위 결과에서 가장 강한 상관관계와 약한 상관관계를 찾아 봅시다.
