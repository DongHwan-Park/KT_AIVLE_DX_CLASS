# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'

# %%
# 내장 라이브러리가 아님, 설치 필요
# !pip install xmltodict

# %%
import xmltodict 
import json           
import pandas     
import urllib
# Parameter 설정
key = 'BjHZZcbP1j%2BVrenVf6W3sbp0PhiHL4LqmwwX8qgUMMPrzw4updVb9kO7numWldmB5V5nb2SJ59%2FW2V1t%2F%2FLOxQ%3D%3D'

# param1, param2 = 'param1', 'param2'
url = f'http://apis.data.go.kr/B552584/EvCharger/getChargerInfo?serviceKey={key}&numOfRows=100&pageNo=1&dataType=XML'
# 데이터 인코딩
response = urllib.request.urlopen(url)

# XML 형식 데이터 Dictionary 자료형으로 변환
xml_parse = xmltodict.parse(response)
xml_dict = json.loads(json.dumps(xml_parse))           # XML 데이터를 JSON 형식으로 변환
result = xml_dict['response']['body']['items']['item']
result
# Dictionary 자료형 데이터로 Dataframe 생성
df = pd.json_normalize(result)

# 확인
df.head()
# Out:
#              statNm    statId chgerId chgerType                  addr  \
# 0          종묘 공영주차장  ME000001      01        03      서울특별시 종로구 종로 157
# 1         세종로 공영주차장  ME000002      01        06    서울특별시 종로구 세종대로 189
# 2        그랜드앰배서더 서울  ME000003      01        06      서울특별시 중구 동호로 287
# 3        한강진역 공영주차장  ME000004      01        03  서울특별시 용산구 한남동 산10-84
# 4  마장동사무소 앞(공중전화부스)  ME000006      01        06     서울특별시 성동구 마장동 808
#
#   location         lat          lng    useTime busiId  ... zcode zscode kind  \
# 0     null   37.571076    126.99588  24시간 이용가능     ME  ...    11  11110   B0
# 1     null   37.573611   126.976011  24시간 이용가능     ME  ...    11  11110   B0
# 2     null   37.559352   127.002350  24시간 이용가능     ME  ...    11  11140   E0
# 3     null   37.540085   127.002804  24시간 이용가능     ME  ...    11  11170   B0
# 4     null  37.5660935  127.0455256  24시간 이용가능     ME  ...    11  11200   G0
#
#   kindDetail parkingFree  note limitYn limitDetail delYn delDetail
# ...
